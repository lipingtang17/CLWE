# %%
import io
from collections import defaultdict

# %%
lang_list = ["en", "de", "es", "it", "fi", "ar", "he", "ms", "ja", "zh", "vi", "th"]

# %%
def load_identical_char_dico(word2id1, word2id2):
    """
    Build a dictionary of identical character strings.
    """
#     pairs = [(w1, w1) for w1 in word2id1.keys() if w1 in word2id2 and len(w1) > 1]
    pairs = [(w1, w1) for w1 in word2id1.keys() if w1 in word2id2]
    if len(pairs) == 0:
        raise Exception("No identical character strings were found. "
                        "Please specify a dictionary.")

    print("Found %i pairs of identical character strings." % len(pairs))

#     # sort the dictionary by source word frequencies
#     pairs = sorted(pairs, key=lambda x: word2id1[x[0]])
#     dico = torch.LongTensor(len(pairs), 2)
#     for i, (word1, word2) in enumerate(pairs):
#         dico[i, 0] = word2id1[word1]
#         dico[i, 1] = word2id2[word2]

    return len(pairs), pairs

# %%
def load_word2id(emb_path, max_vocab=1000, full_vocab=False):
    """
    Reload pretrained embeddings from a text file.
    """
    word2id = {}

    # load pretrained embeddings 
    with io.open(emb_path, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
        for i, line in enumerate(f):
            if i == 0:
                print(line.strip())
                split = line.split()
                num_words = split[0]
                assert len(split) == 2
            else:
                word, _ = line.rstrip().split(' ', 1)
                if not full_vocab:
                    word = word.lower()
                if word in word2id:
                    if full_vocab:
                        print("Word '%s' found twice in %s embedding file"
                                       % (word, 'source' if source else 'target'))
                else:
                    word2id[word] = len(word2id)
            if max_vocab > 0 and len(word2id) >= max_vocab and not full_vocab:
                break

    print("Loaded %i pre-trained word embeddings from %s." % (len(word2id), emb_path))

    return word2id, num_words

# %%
emb_file_list = ["/mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.%s.vec"%lang for lang in lang_list]

# %%
for emb_file_i in emb_file_list:
    word2id1, num_words1 = load_word2id(emb_file_i)
    for emb_file_j in emb_file_list:
        if emb_file_j == emb_file_i:
            continue
        word2id2, num_words2 = load_word2id(emb_file_j)
        load_identical_char_dico(word2id1, word2id2)
# Out:
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 150 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 140 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 141 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 128 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 75 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 44 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 163 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 66 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 84 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 96 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 63 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 150 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 110 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 128 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 110 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 65 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 43 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 116 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 67 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 67 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 81 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 52 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 140 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 110 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 208 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 107 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 72 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 44 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 109 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 67 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 69 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 83 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 56 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 141 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 128 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 208 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 120 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 65 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 39 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 104 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 66 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 67 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 91 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 54 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 128 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 110 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 107 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 120 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 69 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 44 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 105 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 67 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 68 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 78 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 56 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 75 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 65 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 72 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 65 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 69 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 47 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 86 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 55 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 66 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 72 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 58 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 44 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 43 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 44 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 39 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 44 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 47 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 45 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 40 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 42 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 41 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 40 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 163 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 116 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 109 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 104 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 105 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 86 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 45 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 67 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 79 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 106 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 63 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 66 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 67 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 67 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 66 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 67 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 55 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 40 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 67 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 319 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 58 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 49 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 84 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 67 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 69 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 67 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 68 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 66 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 42 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 79 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 319 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 63 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 57 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 96 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 81 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 83 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 91 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 78 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 72 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 41 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 106 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 58 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 63 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 53 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 63 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 52 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 56 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 54 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 56 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 58 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 40 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 63 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 49 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 57 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 53 pairs of identical character strings.

# %%
iden_num = defaultdict(dict)
for lang_i in lang_list:
    emb_file_i = "/mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.%s.vec"%lang_i
    max_vocab = 1000
    word2id1, num_words1 = load_word2id(emb_file_i, max_vocab)
    iden_num[lang_i]["num_words"] = num_words1
    iden_num[lang_i]["max_vocab"] = max_vocab
    
    for lang_j in lang_list:
        emb_file_j = "/mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.%s.vec"%lang_j
        if emb_file_j == emb_file_i:
            continue
        word2id2, num_words2 = load_word2id(emb_file_j, max_vocab)
        iden_tmp, iden_pair = load_identical_char_dico(word2id1, word2id2)
        iden_num[lang_i][lang_j] = {"num": iden_tmp, "pairs": iden_pair}
# Out:
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 109 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 96 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 98 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 85 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 36 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 15 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 121 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 26 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 42 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 57 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 31 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 109 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 70 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 87 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 68 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 27 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 14 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 76 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 25 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 24 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 43 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 20 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 96 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 70 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 163 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 65 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 34 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 15 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 68 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 27 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 28 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 44 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 24 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 98 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 87 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 163 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 78 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 27 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 11 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 63 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 26 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 25 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 52 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 23 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 85 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 68 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 65 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 78 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 31 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 15 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 64 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 26 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 26 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 39 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 24 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 36 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 27 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 34 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 27 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 31 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 18 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 49 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 18 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 28 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 37 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 27 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 15 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 14 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 15 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 11 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 15 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 18 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 17 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 11 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 13 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 13 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 10 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 121 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 76 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 68 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 63 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 64 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 49 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 17 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 28 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 38 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 68 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 32 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 26 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 25 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 27 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 26 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 26 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 18 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 11 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 28 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 94 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 20 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 17 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 42 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 24 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 28 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 25 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 26 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 28 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 13 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 38 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 94 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 25 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 25 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 57 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 43 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 44 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 52 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 39 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 37 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 13 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 68 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 20 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 25 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# Found 23 pairs of identical character strings.
# 107774 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.th.vec.
# 2519370 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.en.vec.
# Found 31 pairs of identical character strings.
# 2275233 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.de.vec.
# Found 20 pairs of identical character strings.
# 985667 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.es.vec.
# Found 24 pairs of identical character strings.
# 871053 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.it.vec.
# Found 23 pairs of identical character strings.
# 730483 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.fi.vec.
# Found 24 pairs of identical character strings.
# 610977 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ar.vec.
# Found 27 pairs of identical character strings.
# 488936 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.he.vec.
# Found 10 pairs of identical character strings.
# 155629 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ms.vec.
# Found 32 pairs of identical character strings.
# 580000 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.ja.vec.
# Found 17 pairs of identical character strings.
# 332647 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.zh.vec.
# Found 25 pairs of identical character strings.
# 292168 300
# Loaded 1000 pre-trained word embeddings from /mnt/ssd-201-112-01/cpii.local/lptang/WordEmb/fasttext/wiki.vi.vec.
# Found 23 pairs of identical character strings.

# %%
# max_vocab = 10000
iden_num
# Out:
# defaultdict(dict,
#             {'en': {'num_words': '2519370',
#               'max_vocab': 1000,
#               'de': {'num': 109,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('was', 'was'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('an', 'an'),
#                 ('also', 'also'),
#                 ('rd', 'rd'),
#                 ('new', 'new'),
#                 ('all', 'all'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('american', 'american'),
#                 ('links', 'links'),
#                 ('see', 'see'),
#                 ('so', 'so'),
#                 ('world', 'world'),
#                 ('university', 'university'),
#                 ('national', 'national'),
#                 ('wikipedia', 'wikipedia'),
#                 ('city', 'city'),
#                 ('county', 'county'),
#                 ('will', 'will'),
#                 ('de', 'de'),
#                 ('august', 'august'),
#                 ('film', 'film'),
#                 ('september', 'september'),
#                 ('war', 'war'),
#                 ('april', 'april'),
#                 ('november', 'november'),
#                 ('name', 'name'),
#                 ('st', 'st'),
#                 ('league', 'league'),
#                 ('john', 'john'),
#                 ('album', 'album'),
#                 ('york', 'york'),
#                 ('international', 'international'),
#                 ('west', 'west'),
#                 ('general', 'general'),
#                 ('center', 'center'),
#                 ('per', 'per'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('system', 'system'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('band', 'band'),
#                 ('top', 'top'),
#                 ('main', 'main'),
#                 ('https', 'https'),
#                 ('us', 'us'),
#                 ('website', 'website'),
#                 ('ii', 'ii'),
#                 ('park', 'park'),
#                 ('london', 'london'),
#                 ('art', 'art'),
#                 ('award', 'award'),
#                 ('england', 'england'),
#                 ('man', 'man'),
#                 ('version', 'version'),
#                 ('la', 'la'),
#                 ('division', 'division'),
#                 ('form', 'form'),
#                 ('am', 'am'),
#                 ('region', 'region'),
#                 ('william', 'william'),
#                 ('san', 'san'),
#                 ('james', 'james'),
#                 ('http', 'http'),
#                 ('george', 'george'),
#                 ('jpg', 'jpg'),
#                 ('land', 'land'),
#                 ('tv', 'tv'),
#                 ('al', 'al'),
#                 ('david', 'david'),
#                 ('//www', '//www'),
#                 ('press', 'press'),
#                 ('person', 'person'),
#                 ('museum', 'museum'),
#                 ('robert', 'robert'),
#                 ('isbn', 'isbn'),
#                 ('china', 'china'),
#                 ('paul', 'paul'),
#                 ('michael', 'michael'),
#                 ('thomas', 'thomas'),
#                 ('charles', 'charles'),
#                 ('roman', 'roman'),
#                 ('bar', 'bar'),
#                 ('problem', 'problem'),
#                 ('google', 'google'),
#                 ('saint', 'saint'),
#                 ('peter', 'peter'),
#                 ('christian', 'christian'),
#                 ('richard', 'richard'),
#                 ('dr', 'dr'),
#                 ('fc', 'fc'),
#                 ('etc', 'etc'),
#                 ('paris', 'paris'),
#                 ('online', 'online'),
#                 ('professor', 'professor'),
#                 ('van', 'van')]},
#               'es': {'num': 96,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('from', 'from'),
#                 ('he', 'he'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('new', 'new'),
#                 ('no', 'no'),
#                 ('you', 'you'),
#                 ('may', 'may'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('do', 'do'),
#                 ('world', 'world'),
#                 ('wikipedia', 'wikipedia'),
#                 ('city', 'city'),
#                 ('de', 'de'),
#                 ('series', 'series'),
#                 ('john', 'john'),
#                 ('york', 'york'),
#                 ('me', 'me'),
#                 ('club', 'club'),
#                 ('general', 'general'),
#                 ('don', 'don'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('local', 'local'),
#                 ('top', 'top'),
#                 ('https', 'https'),
#                 ('original', 'original'),
#                 ('ii', 'ii'),
#                 ('final', 'final'),
#                 ('central', 'central'),
#                 ('california', 'california'),
#                 ('media', 'media'),
#                 ('la', 'la'),
#                 ('research', 'research'),
#                 ('records', 'records'),
#                 ('near', 'near'),
#                 ('australia', 'australia'),
#                 ('radio', 'radio'),
#                 ('india', 'india'),
#                 ('william', 'william'),
#                 ('son', 'son'),
#                 ('red', 'red'),
#                 ('san', 'san'),
#                 ('james', 'james'),
#                 ('director', 'director'),
#                 ('http', 'http'),
#                 ('jpg', 'jpg'),
#                 ('tv', 'tv'),
#                 ('al', 'al'),
#                 ('total', 'total'),
#                 ('david', 'david'),
#                 ('rock', 'rock'),
#                 ('//www', '//www'),
#                 ('social', 'social'),
#                 ('similar', 'similar'),
#                 ('color', 'color'),
#                 ('robert', 'robert'),
#                 ('isbn', 'isbn'),
#                 ('control', 'control'),
#                 ('real', 'real'),
#                 ('personal', 'personal'),
#                 ('china', 'china'),
#                 ('paul', 'paul'),
#                 ('popular', 'popular'),
#                 ('civil', 'civil'),
#                 ('sea', 'sea'),
#                 ('bar', 'bar'),
#                 ('saint', 'saint'),
#                 ('festival', 'festival'),
#                 ('los', 'los'),
#                 ('material', 'material'),
#                 ('federal', 'federal'),
#                 ('musical', 'musical'),
#                 ('border', 'border'),
#                 ('debut', 'debut'),
#                 ('fc', 'fc'),
#                 ('actor', 'actor'),
#                 ('natural', 'natural'),
#                 ('etc', 'etc'),
#                 ('base', 'base'),
#                 ('capital', 'capital'),
#                 ('van', 'van')]},
#               'it': {'num': 98,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('it', 'it'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('rd', 'rd'),
#                 ('new', 'new'),
#                 ('no', 'no'),
#                 ('you', 'you'),
#                 ('all', 'all'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('world', 'world'),
#                 ('state', 'state'),
#                 ('wikipedia', 'wikipedia'),
#                 ('city', 'city'),
#                 ('de', 'de'),
#                 ('film', 'film'),
#                 ('football', 'football'),
#                 ('league', 'league'),
#                 ('john', 'john'),
#                 ('album', 'album'),
#                 ('area', 'area'),
#                 ('york', 'york'),
#                 ('me', 'me'),
#                 ('club', 'club'),
#                 ('left', 'left'),
#                 ('don', 'don'),
#                 ('center', 'center'),
#                 ('per', 'per'),
#                 ('style', 'style'),
#                 ('non', 'non'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('}}', '}}'),
#                 ('set', 'set'),
#                 ('text', 'text'),
#                 ('band', 'band'),
#                 ('top', 'top'),
#                 ('note', 'note'),
#                 ('re', 're'),
#                 ('ii', 'ii'),
#                 ('due', 'due'),
#                 ('man', 'man'),
#                 ('media', 'media'),
#                 ('black', 'black'),
#                 ('la', 'la'),
#                 ('record', 'record'),
#                 ('records', 'records'),
#                 ('video', 'video'),
#                 ('radio', 'radio'),
#                 ('live', 'live'),
#                 ('william', 'william'),
#                 ('san', 'san'),
#                 ('james', 'james'),
#                 ('http', 'http'),
#                 ('id', 'id'),
#                 ('george', 'george'),
#                 ('jpg', 'jpg'),
#                 ('file', 'file'),
#                 ('tv', 'tv'),
#                 ('america', 'america'),
#                 ('al', 'al'),
#                 ('david', 'david'),
#                 ('rock', 'rock'),
#                 ('love', 'love'),
#                 ('data', 'data'),
#                 ('color', 'color'),
#                 ('robert', 'robert'),
#                 ('isbn', 'isbn'),
#                 ('start', 'start'),
#                 ('star', 'star'),
#                 ('paul', 'paul'),
#                 ('far', 'far'),
#                 ('michael', 'michael'),
#                 ('thomas', 'thomas'),
#                 ('via', 'via'),
#                 ('charles', 'charles'),
#                 ('template', 'template'),
#                 ('come', 'come'),
#                 ('tour', 'tour'),
#                 ('bar', 'bar'),
#                 ('saint', 'saint'),
#                 ('festival', 'festival'),
#                 ('peter', 'peter'),
#                 ('value', 'value'),
#                 ('los', 'los'),
#                 ('richard', 'richard'),
#                 ('border', 'border'),
#                 ('base', 'base'),
#                 ('studio', 'studio'),
#                 ('van', 'van')]},
#               'fi': {'num': 85,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('is', 'is'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('as', 'as'),
#                 ('it', 'it'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('he', 'he'),
#                 ('utc', 'utc'),
#                 ('new', 'new'),
#                 ('no', 'no'),
#                 ('you', 'you'),
#                 ('all', 'all'),
#                 ('if', 'if'),
#                 ('world', 'world'),
#                 ('national', 'national'),
#                 ('wikipedia', 'wikipedia'),
#                 ('city', 'city'),
#                 ('de', 'de'),
#                 ('my', 'my'),
#                 ('st', 'st'),
#                 ('music', 'music'),
#                 ('diff', 'diff'),
#                 ('john', 'john'),
#                 ('york', 'york'),
#                 ('me', 'me'),
#                 ('international', 'international'),
#                 ('don', 'don'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('www', 'www'),
#                 ('single', 'single'),
#                 ('align', 'align'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('https', 'https'),
#                 ('ii', 'ii'),
#                 ('man', 'man'),
#                 ('black', 'black'),
#                 ('php', 'php'),
#                 ('la', 'la'),
#                 ('cup', 'cup'),
#                 ('records', 'records'),
#                 ('radio', 'radio'),
#                 ('live', 'live'),
#                 ('william', 'william'),
#                 ('red', 'red'),
#                 ('san', 'san'),
#                 ('james', 'james'),
#                 ('http', 'http'),
#                 ('george', 'george'),
#                 ('org/w/index', 'org/w/index'),
#                 ('jpg', 'jpg'),
#                 ('tv', 'tv'),
#                 ('al', 'al'),
#                 ('david', 'david'),
#                 ('rock', 'rock'),
#                 ('//www', '//www'),
#                 ('love', 'love'),
#                 ('color', 'color'),
#                 ('bgcolor', 'bgcolor'),
#                 ('robert', 'robert'),
#                 ('isbn', 'isbn'),
#                 ('paul', 'paul'),
#                 ('michael', 'michael'),
#                 ('thomas', 'thomas'),
#                 ('charles', 'charles'),
#                 ('italian', 'italian'),
#                 ('saint', 'saint'),
#                 ('grand', 'grand'),
#                 ('peter', 'peter'),
#                 ('los', 'los'),
#                 ('richard', 'richard'),
#                 ('border', 'border'),
#                 ('reference', 'reference'),
#                 ('fc', 'fc'),
#                 ('van', 'van')]},
#               'ar': {'num': 36,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('is', 'is'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('if', 'if'),
#                 ('team', 'team'),
#                 ('world', 'world'),
#                 ('wikipedia', 'wikipedia'),
#                 ('de', 'de'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('right', 'right'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('https', 'https'),
#                 ('subdivision_type', 'subdivision_type'),
#                 ('http', 'http'),
#                 ('jpg', 'jpg'),
#                 ('subdivision_name', 'subdivision_name'),
#                 ('//www', '//www'),
#                 ('background', 'background'),
#                 ('color', 'color'),
#                 ('border', 'border')]},
#               'he': {'num': 15,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('}}', '}}'),
#                 ('https', 'https'),
#                 ('jpg', 'jpg'),
#                 ('//www', '//www'),
#                 ('bgcolor', 'bgcolor')]},
#               'ms': {'num': 121,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('is', 'is'),
#                 ('was', 'was'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('as', 'as'),
#                 ('by', 'by'),
#                 ('that', 'that'),
#                 ('it', 'it'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('this', 'this'),
#                 ('be', 'be'),
#                 ('an', 'an'),
#                 ('utc', 'utc'),
#                 ('not', 'not'),
#                 ('are', 'are'),
#                 ('or', 'or'),
#                 ('one', 'one'),
#                 ('rd', 'rd'),
#                 ('new', 'new'),
#                 ('first', 'first'),
#                 ('no', 'no'),
#                 ('you', 'you'),
#                 ('all', 'all'),
#                 ('score', 'score'),
#                 ('if', 'if'),
#                 ('team', 'team'),
#                 ('united', 'united'),
#                 ('years', 'years'),
#                 ('world', 'world'),
#                 ('university', 'university'),
#                 ('national', 'national'),
#                 ('wikipedia', 'wikipedia'),
#                 ('city', 'city'),
#                 ('then', 'then'),
#                 ('de', 'de'),
#                 ('september', 'september'),
#                 ('april', 'april'),
#                 ('november', 'november'),
#                 ('list', 'list'),
#                 ('name', 'name'),
#                 ('group', 'group'),
#                 ('st', 'st'),
#                 ('john', 'john'),
#                 ('album', 'album'),
#                 ('york', 'york'),
#                 ('british', 'british'),
#                 ('club', 'club'),
#                 ('left', 'left'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('country', 'country'),
#                 ('image', 'image'),
#                 ('right', 'right'),
#                 ('single', 'single'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('goals', 'goals'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('top', 'top'),
#                 ('established', 'established'),
#                 ('website', 'website'),
#                 ('air', 'air'),
#                 ('military', 'military'),
#                 ('ii', 'ii'),
#                 ('clubs', 'clubs'),
#                 ('london', 'london'),
#                 ('england', 'england'),
#                 ('media', 'media'),
#                 ('report', 'report'),
#                 ('la', 'la'),
#                 ('stadium', 'stadium'),
#                 ('australia', 'australia'),
#                 ('video', 'video'),
#                 ('radio', 'radio'),
#                 ('india', 'india'),
#                 ('san', 'san'),
#                 ('subdivision_type', 'subdivision_type'),
#                 ('http', 'http'),
#                 ('jpg', 'jpg'),
#                 ('file', 'file'),
#                 ('tv', 'tv'),
#                 ('subdivision_name', 'subdivision_name'),
#                 ('al', 'al'),
#                 ('//www', '//www'),
#                 ('kingdom', 'kingdom'),
#                 ('program', 'program'),
#                 ('background', 'background'),
#                 ('data', 'data'),
#                 ('color', 'color'),
#                 ('bgcolor', 'bgcolor'),
#                 ('location', 'location'),
#                 ('birth_place', 'birth_place'),
#                 ('isbn', 'isbn'),
#                 ('china', 'china'),
#                 ('popular', 'popular'),
#                 ('founded', 'founded'),
#                 ('republic', 'republic'),
#                 ('caps', 'caps'),
#                 ('aircraft', 'aircraft'),
#                 ('bar', 'bar'),
#                 ('google', 'google'),
#                 ('ireland', 'ireland'),
#                 ('saint', 'saint'),
#                 ('model', 'model'),
#                 ('border', 'border'),
#                 ('dr', 'dr'),
#                 ('label', 'label'),
#                 ('reference', 'reference'),
#                 ('fc', 'fc'),
#                 ('bank', 'bank'),
#                 ('referee', 'referee')]},
#               'ja': {'num': 26,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('utc', 'utc'),
#                 ('or', 'or'),
#                 ('rd', 'rd'),
#                 ('no', 'no'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('de', 'de'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('www', 'www'),
#                 ('align', 'align'),
#                 ('text', 'text'),
#                 ('ii', 'ii'),
#                 ('jpg', 'jpg'),
#                 ('file', 'file'),
#                 ('tv', 'tv'),
#                 ('isbn', 'isbn'),
#                 ('fc', 'fc')]},
#               'zh': {'num': 42,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('by', 'by'),
#                 ('utc', 'utc'),
#                 ('or', 'or'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('wikipedia', 'wikipedia'),
#                 ('de', 'de'),
#                 ('list', 'list'),
#                 ('name', 'name'),
#                 ('group', 'group'),
#                 ('title', 'title'),
#                 ('left', 'left'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('www', 'www'),
#                 ('right', 'right'),
#                 ('align', 'align'),
#                 ('seed', 'seed'),
#                 ('goals', 'goals'),
#                 ('text', 'text'),
#                 ('https', 'https'),
#                 ('original', 'original'),
#                 ('php', 'php'),
#                 ('http', 'http'),
#                 ('jpg', 'jpg'),
#                 ('file', 'file'),
#                 ('background', 'background'),
#                 ('color', 'color'),
#                 ('bgcolor', 'bgcolor'),
#                 ('isbn', 'isbn'),
#                 ('border', 'border'),
#                 ('org', 'org')]},
#               'vi': {'num': 57,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('is', 'is'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('by', 'by'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('an', 'an'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('new', 'new'),
#                 ('score', 'score'),
#                 ('american', 'american'),
#                 ('do', 'do'),
#                 ('so', 'so'),
#                 ('world', 'world'),
#                 ('wikipedia', 'wikipedia'),
#                 ('de', 'de'),
#                 ('list', 'list'),
#                 ('john', 'john'),
#                 ('album', 'album'),
#                 ('club', 'club'),
#                 ('left', 'left'),
#                 ('style', 'style'),
#                 ('long', 'long'),
#                 ('right', 'right'),
#                 ('song', 'song'),
#                 ('align', 'align'),
#                 ('goals', 'goals'),
#                 ('}}', '}}'),
#                 ('text', 'text'),
#                 ('top', 'top'),
#                 ('website', 'website'),
#                 ('ii', 'ii'),
#                 ('la', 'la'),
#                 ('species', 'species'),
#                 ('red', 'red'),
#                 ('san', 'san'),
#                 ('subdivision_type', 'subdivision_type'),
#                 ('id', 'id'),
#                 ('jpg', 'jpg'),
#                 ('subdivision_name', 'subdivision_name'),
#                 ('data', 'data'),
#                 ('color', 'color'),
#                 ('isbn', 'isbn'),
#                 ('caps', 'caps'),
#                 ('bar', 'bar'),
#                 ('saint', 'saint'),
#                 ('value', 'value'),
#                 ('names', 'names'),
#                 ('bay', 'bay'),
#                 ('paris', 'paris')]},
#               'th': {'num': 31,
#                'pairs': [('the', 'the'),
#                 ('</s>', '</s>'),
#                 ('of', 'of'),
#                 ('in', 'in'),
#                 ('and', 'and'),
#                 ('to', 'to'),
#                 ('is', 'is'),
#                 ('on', 'on'),
#                 ('for', 'for'),
#                 ('by', 'by'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('th', 'th'),
#                 ('group', 'group'),
#                 ('center', 'center'),
#                 ('style', 'style'),
#                 ('com', 'com'),
#                 ('www', 'www'),
#                 ('align', 'align'),
#                 ('goals', 'goals'),
#                 ('text', 'text'),
#                 ('stadium', 'stadium'),
#                 ('http', 'http'),
#                 ('jpg', 'jpg'),
#                 ('data', 'data'),
#                 ('color', 'color'),
#                 ('border', 'border')]}},
#              'de': {'num_words': '2275233',
#               'max_vocab': 1000,
#               'en': {'num': 109,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('an', 'an'),
#                 ('war', 'war'),
#                 ('rd', 'rd'),
#                 ('am', 'am'),
#                 ('score', 'score'),
#                 ('so', 'so'),
#                 ('man', 'man'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('was', 'was'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('us', 'us'),
#                 ('august', 'august'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('band', 'band'),
#                 ('also', 'also'),
#                 ('wikipedia', 'wikipedia'),
#                 ('april', 'april'),
#                 ('september', 'september'),
#                 ('jpg', 'jpg'),
#                 ('november', 'november'),
#                 ('st', 'st'),
#                 ('film', 'film'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('art', 'art'),
#                 ('name', 'name'),
#                 ('peter', 'peter'),
#                 ('}}', '}}'),
#                 ('form', 'form'),
#                 ('john', 'john'),
#                 ('york', 'york'),
#                 ('paul', 'paul'),
#                 ('university', 'university'),
#                 ('land', 'land'),
#                 ('paris', 'paris'),
#                 ('michael', 'michael'),
#                 ('region', 'region'),
#                 ('website', 'website'),
#                 ('align', 'align'),
#                 ('will', 'will'),
#                 ('to', 'to'),
#                 ('london', 'london'),
#                 ('album', 'album'),
#                 ('museum', 'museum'),
#                 ('thomas', 'thomas'),
#                 ('https', 'https'),
#                 ('robert', 'robert'),
#                 ('bar', 'bar'),
#                 ('county', 'county'),
#                 ('http', 'http'),
#                 ('version', 'version'),
#                 ('international', 'international'),
#                 ('for', 'for'),
#                 ('//www', '//www'),
#                 ('style', 'style'),
#                 ('links', 'links'),
#                 ('from', 'from'),
#                 ('fc', 'fc'),
#                 ('online', 'online'),
#                 ('professor', 'professor'),
#                 ('christian', 'christian'),
#                 ('dr', 'dr'),
#                 ('saint', 'saint'),
#                 ('on', 'on'),
#                 ('van', 'van'),
#                 ('problem', 'problem'),
#                 ('al', 'al'),
#                 ('national', 'national'),
#                 ('david', 'david'),
#                 ('richard', 'richard'),
#                 ('san', 'san'),
#                 ('center', 'center'),
#                 ('system', 'system'),
#                 ('at', 'at'),
#                 ('main', 'main'),
#                 ('west', 'west'),
#                 ('per', 'per'),
#                 ('roman', 'roman'),
#                 ('william', 'william'),
#                 ('person', 'person'),
#                 ('city', 'city'),
#                 ('com', 'com'),
#                 ('world', 'world'),
#                 ('google', 'google'),
#                 ('general', 'general'),
#                 ('james', 'james'),
#                 ('top', 'top'),
#                 ('england', 'england'),
#                 ('see', 'see'),
#                 ('tv', 'tv'),
#                 ('etc', 'etc'),
#                 ('park', 'park'),
#                 ('george', 'george'),
#                 ('award', 'award'),
#                 ('league', 'league'),
#                 ('division', 'division'),
#                 ('charles', 'charles'),
#                 ('american', 'american'),
#                 ('china', 'china'),
#                 ('all', 'all'),
#                 ('press', 'press')]},
#               'es': {'num': 70,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('des', 'des'),
#                 ('es', 'es'),
#                 ('rd', 'rd'),
#                 ('cest', 'cest'),
#                 ('cet', 'cet'),
#                 ('score', 'score'),
#                 ('da', 'da'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jpg', 'jpg'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('}}', '}}'),
#                 ('john', 'john'),
#                 ('usa', 'usa'),
#                 ('york', 'york'),
#                 ('paul', 'paul'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('https', 'https'),
#                 ('robert', 'robert'),
#                 ('iii', 'iii'),
#                 ('bar', 'bar'),
#                 ('http', 'http'),
#                 ('et', 'et'),
#                 ('autor', 'autor'),
#                 ('for', 'for'),
#                 ('serie', 'serie'),
#                 ('le', 'le'),
#                 ('//www', '//www'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('europa', 'europa'),
#                 ('fc', 'fc'),
#                 ('saint', 'saint'),
#                 ('on', 'on'),
#                 ('van', 'van'),
#                 ('al', 'al'),
#                 ('david', 'david'),
#                 ('san', 'san'),
#                 ('center', 'center'),
#                 ('en', 'en'),
#                 ('liga', 'liga'),
#                 ('di', 'di'),
#                 ('william', 'william'),
#                 ('jean', 'jean'),
#                 ('mm', 'mm'),
#                 ('city', 'city'),
#                 ('com', 'com'),
#                 ('world', 'world'),
#                 ('general', 'general'),
#                 ('james', 'james'),
#                 ('top', 'top'),
#                 ('tv', 'tv'),
#                 ('etc', 'etc'),
#                 ('cm', 'cm'),
#                 ('dar', 'dar'),
#                 ('iv', 'iv'),
#                 ('china', 'china')]},
#               'it': {'num': 87,
#                'pairs': [('</s>', '</s>'),
#                 ('der', 'der'),
#                 ('in', 'in'),
#                 ('von', 'von'),
#                 ('des', 'des'),
#                 ('rd', 'rd'),
#                 ('cest', 'cest'),
#                 ('cet', 'cet'),
#                 ('score', 'score'),
#                 ('man', 'man'),
#                 ('da', 'da'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('mai', 'mai'),
#                 ('isbn', 'isbn'),
#                 ('team', 'team'),
#                 ('du', 'du'),
#                 ('seed', 'seed'),
#                 ('alle', 'alle'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('band', 'band'),
#                 ('nov', 'nov'),
#                 ('wikipedia', 'wikipedia'),
#                 ('feb', 'feb'),
#                 ('apr', 'apr'),
#                 ('jpg', 'jpg'),
#                 ('film', 'film'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('peter', 'peter'),
#                 ('sei', 'sei'),
#                 ('}}', '}}'),
#                 ('john', 'john'),
#                 ('usa', 'usa'),
#                 ('york', 'york'),
#                 ('paul', 'paul'),
#                 ('quelle', 'quelle'),
#                 ('michael', 'michael'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('album', 'album'),
#                 ('thomas', 'thomas'),
#                 ('maria', 'maria'),
#                 ('martin', 'martin'),
#                 ('robert', 'robert'),
#                 ('iii', 'iii'),
#                 ('bar', 'bar'),
#                 ('http', 'http'),
#                 ('et', 'et'),
#                 ('for', 'for'),
#                 ('serie', 'serie'),
#                 ('le', 'le'),
#                 ('style', 'style'),
#                 ('otto', 'otto'),
#                 ('from', 'from'),
#                 ('europa', 'europa'),
#                 ('saint', 'saint'),
#                 ('on', 'on'),
#                 ('van', 'van'),
#                 ('al', 'al'),
#                 ('david', 'david'),
#                 ('richard', 'richard'),
#                 ('san', 'san'),
#                 ('center', 'center'),
#                 ('at', 'at'),
#                 ('en', 'en'),
#                 ('per', 'per'),
#                 ('di', 'di'),
#                 ('william', 'william'),
#                 ('jean', 'jean'),
#                 ('mm', 'mm'),
#                 ('city', 'city'),
#                 ('world', 'world'),
#                 ('james', 'james'),
#                 ('top', 'top'),
#                 ('tv', 'tv'),
#                 ('george', 'george'),
#                 ('cm', 'cm'),
#                 ('league', 'league'),
#                 ('charles', 'charles'),
#                 ('till', 'till'),
#                 ('iv', 'iv'),
#                 ('all', 'all')]},
#               'fi': {'num': 68,
#                'pairs': [('</s>', '</s>'),
#                 ('der', 'der'),
#                 ('in', 'in'),
#                 ('von', 'von'),
#                 ('man', 'man'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('alle', 'alle'),
#                 ('ja', 'ja'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jpg', 'jpg'),
#                 ('st', 'st'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('peter', 'peter'),
#                 ('}}', '}}'),
#                 ('john', 'john'),
#                 ('york', 'york'),
#                 ('paul', 'paul'),
#                 ('michael', 'michael'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('thomas', 'thomas'),
#                 ('maria', 'maria'),
#                 ('martin', 'martin'),
#                 ('https', 'https'),
#                 ('robert', 'robert'),
#                 ('iii', 'iii'),
#                 ('http', 'http'),
#                 ('international', 'international'),
#                 ('et', 'et'),
#                 ('for', 'for'),
#                 ('le', 'le'),
#                 ('//www', '//www'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('fc', 'fc'),
#                 ('saint', 'saint'),
#                 ('carl', 'carl'),
#                 ('on', 'on'),
#                 ('van', 'van'),
#                 ('al', 'al'),
#                 ('national', 'national'),
#                 ('david', 'david'),
#                 ('richard', 'richard'),
#                 ('san', 'san'),
#                 ('center', 'center'),
#                 ('at', 'at'),
#                 ('en', 'en'),
#                 ('william', 'william'),
#                 ('jean', 'jean'),
#                 ('mm', 'mm'),
#                 ('city', 'city'),
#                 ('com', 'com'),
#                 ('world', 'world'),
#                 ('james', 'james'),
#                 ('tv', 'tv'),
#                 ('george', 'george'),
#                 ('cm', 'cm'),
#                 ('charles', 'charles'),
#                 ('kg', 'kg'),
#                 ('all', 'all')]},
#               'ar': {'num': 27,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('and', 'and'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jpg', 'jpg'),
#                 ('text', 'text'),
#                 ('}}', '}}'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('https', 'https'),
#                 ('http', 'http'),
#                 ('for', 'for'),
#                 ('//www', '//www'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('on', 'on'),
#                 ('center', 'center'),
#                 ('at', 'at'),
#                 ('com', 'com'),
#                 ('world', 'world')]},
#               'he': {'num': 14,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('ist', 'ist'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('}}', '}}'),
#                 ('to', 'to'),
#                 ('https', 'https'),
#                 ('//www', '//www')]},
#               'ms': {'num': 76,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('an', 'an'),
#                 ('rd', 'rd'),
#                 ('cest', 'cest'),
#                 ('cet', 'cet'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('was', 'was'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('oktober', 'oktober'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jun', 'jun'),
#                 ('april', 'april'),
#                 ('september', 'september'),
#                 ('jpg', 'jpg'),
#                 ('november', 'november'),
#                 ('st', 'st'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('name', 'name'),
#                 ('}}', '}}'),
#                 ('meter', 'meter'),
#                 ('john', 'john'),
#                 ('bin', 'bin'),
#                 ('york', 'york'),
#                 ('university', 'university'),
#                 ('website', 'website'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('london', 'london'),
#                 ('album', 'album'),
#                 ('bar', 'bar'),
#                 ('http', 'http'),
#                 ('et', 'et'),
#                 ('for', 'for'),
#                 ('le', 'le'),
#                 ('//www', '//www'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('fc', 'fc'),
#                 ('dr', 'dr'),
#                 ('saint', 'saint'),
#                 ('on', 'on'),
#                 ('al', 'al'),
#                 ('national', 'national'),
#                 ('laut', 'laut'),
#                 ('san', 'san'),
#                 ('center', 'center'),
#                 ('at', 'at'),
#                 ('kaum', 'kaum'),
#                 ('en', 'en'),
#                 ('liga', 'liga'),
#                 ('di', 'di'),
#                 ('tun', 'tun'),
#                 ('mm', 'mm'),
#                 ('city', 'city'),
#                 ('com', 'com'),
#                 ('world', 'world'),
#                 ('google', 'google'),
#                 ('republik', 'republik'),
#                 ('top', 'top'),
#                 ('england', 'england'),
#                 ('tv', 'tv'),
#                 ('till', 'till'),
#                 ('rom', 'rom'),
#                 ('china', 'china'),
#                 ('all', 'all')]},
#               'ja': {'num': 25,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('team', 'team'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('for', 'for'),
#                 ('style', 'style'),
#                 ('fc', 'fc'),
#                 ('on', 'on'),
#                 ('mm', 'mm'),
#                 ('com', 'com'),
#                 ('tv', 'tv'),
#                 ('cm', 'cm'),
#                 ('kg', 'kg')]},
#               'zh': {'num': 24,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('and', 'and'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jpg', 'jpg'),
#                 ('text', 'text'),
#                 ('name', 'name'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('https', 'https'),
#                 ('http', 'http'),
#                 ('for', 'for'),
#                 ('style', 'style'),
#                 ('on', 'on'),
#                 ('center', 'center'),
#                 ('com', 'com')]},
#               'vi': {'num': 43,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('an', 'an'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('so', 'so'),
#                 ('da', 'da'),
#                 ('de', 'de'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('isbn', 'isbn'),
#                 ('du', 'du'),
#                 ('la', 'la'),
#                 ('and', 'and'),
#                 ('wikipedia', 'wikipedia'),
#                 ('jpg', 'jpg'),
#                 ('new', 'new'),
#                 ('ii', 'ii'),
#                 ('text', 'text'),
#                 ('km', 'km'),
#                 ('}}', '}}'),
#                 ('john', 'john'),
#                 ('ca', 'ca'),
#                 ('paris', 'paris'),
#                 ('website', 'website'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('album', 'album'),
#                 ('bar', 'bar'),
#                 ('et', 'et'),
#                 ('for', 'for'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('saint', 'saint'),
#                 ('on', 'on'),
#                 ('san', 'san'),
#                 ('at', 'at'),
#                 ('di', 'di'),
#                 ('mm', 'mm'),
#                 ('world', 'world'),
#                 ('top', 'top'),
#                 ('american', 'american'),
#                 ('till', 'till')]},
#               'th': {'num': 20,
#                'pairs': [('</s>', '</s>'),
#                 ('in', 'in'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('team', 'team'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('text', 'text'),
#                 ('align', 'align'),
#                 ('to', 'to'),
#                 ('http', 'http'),
#                 ('for', 'for'),
#                 ('style', 'style'),
#                 ('from', 'from'),
#                 ('on', 'on'),
#                 ('center', 'center'),
#                 ('at', 'at'),
#                 ('com', 'com')]}},
#              'es': {'num_words': '985667',
#               'max_vocab': 1000,
#               'en': {'num': 96,
#                'pairs': [('de', 'de'),
#                 ('</s>', '</s>'),
#                 ('la', 'la'),
#                 ('los', 'los'),
#                 ('al', 'al'),
#                 ('rd', 'rd'),
#                 ('no', 'no'),
#                 ('score', 'score'),
#                 ('the', 'the'),
#                 ('son', 'son'),
#                 ('of', 'of'),
#                 ('san', 'san'),
#                 ('team', 'team'),
#                 ('seed', 'seed'),
#                 ('utc', 'utc'),
#                 ('club', 'club'),
#                 ('general', 'general'),
#                 ('and', 'and'),
#                 ('final', 'final'),
#                 ('in', 'in'),
#                 ('total', 'total'),
#                 ('me', 'me'),
#                 ('real', 'real'),
#                 ('ii', 'ii'),
#                 ('color', 'color'),
#                 ('near', 'near'),
#                 ('align', 'align'),
#                 ('central', 'central'),
#                 ('york', 'york'),
#                 ('isbn', 'isbn'),
#                 ('http', 'http'),
#                 ('director', 'director'),
#                 ('research', 'research'),
#                 ('jpg', 'jpg'),
#                 ('base', 'base'),
#                 ('to', 'to'),
#                 ('john', 'john'),
#                 ('capital', 'capital'),
#                 ('center', 'center'),
#                 ('sea', 'sea'),
#                 ('wikipedia', 'wikipedia'),
#                 ('local', 'local'),
#                 ('//www', '//www'),
#                 ('com', 'com'),
#                 ('social', 'social'),
#                 ('rock', 'rock'),
#                 ('popular', 'popular'),
#                 ('original', 'original'),
#                 ('new', 'new'),
#                 ('style', 'style'),
#                 ('media', 'media'),
#                 ('california', 'california'),
#                 ('radio', 'radio'),
#                 ('world', 'world'),
#                 ('red', 'red'),
#                 ('musical', 'musical'),
#                 ('}}', '}}'),
#                 ('china', 'china'),
#                 ('van', 'van'),
#                 ('don', 'don'),
#                 ('civil', 'civil'),
#                 ('natural', 'natural'),
#                 ('etc', 'etc'),
#                 ('for', 'for'),
#                 ('actor', 'actor'),
#                 ('control', 'control'),
#                 ('festival', 'festival'),
#                 ('david', 'david'),
#                 ('on', 'on'),
#                 ('saint', 'saint'),
#                 ('from', 'from'),
#                 ('he', 'he'),
#                 ('series', 'series'),
#                 ('tv', 'tv'),
#                 ('border', 'border'),
#                 ('personal', 'personal'),
#                 ('robert', 'robert'),
#                 ('debut', 'debut'),
#                 ('australia', 'australia'),
#                 ('text', 'text'),
#                 ('federal', 'federal'),
#                 ('city', 'city'),
#                 ('india', 'india'),
#                 ('do', 'do'),
# ...
#                 ('mm', 'mm'),
#                 ('world', 'world'),
#                 ('sai', 'sai'),
#                 ('isbn', 'isbn'),
#                 ('}}}', '}}}'),
#                 ('saint', 'saint'),
#                 ('wikipedia', 'wikipedia'),
#                 ('px', 'px'),
#                 ('red', 'red'),
#                 ('et', 'et'),
#                 ('color', 'color'),
#                 ('john', 'john'),
#                 ('is', 'is')]},
#               'ar': {'num': 37,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('subdivision_name', 'subdivision_name'),
#                 ('text', 'text'),
#                 ('subdivision_type', 'subdivision_type'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('de', 'de'),
#                 ('in', 'in'),
#                 ('utc', 'utc'),
#                 ('latns', 'latns'),
#                 ('longew', 'longew'),
#                 ('longd', 'longd'),
#                 ('latd', 'latd'),
#                 ('latm', 'latm'),
#                 ('longm', 'longm'),
#                 ('lats', 'lats'),
#                 ('longs', 'longs'),
#                 ('rd', 'rd'),
#                 ('}}', '}}'),
#                 ('score', 'score'),
#                 ('to', 'to'),
#                 ('align', 'align'),
#                 ('on', 'on'),
#                 ('style', 'style'),
#                 ('for', 'for'),
#                 ('world', 'world'),
#                 ('right', 'right'),
#                 ('}}}', '}}}'),
#                 ('width', 'width'),
#                 ('wikipedia', 'wikipedia'),
#                 ('px', 'px'),
#                 ('color', 'color'),
#                 ('is', 'is')]},
#               'he': {'num': 13,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('de', 'de'),
#                 ('in', 'in'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('}}', '}}'),
#                 ('score', 'score'),
#                 ('to', 'to'),
#                 ('}}}', '}}}')]},
#               'ms': {'num': 68,
#                'pairs': [('</s>', '</s>'),
#                 ('bar', 'bar'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('subdivision_name', 'subdivision_name'),
#                 ('text', 'text'),
#                 ('subdivision_type', 'subdivision_type'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('de', 'de'),
#                 ('an', 'an'),
#                 ('till', 'till'),
#                 ('in', 'in'),
#                 ('timezone', 'timezone'),
#                 ('utc_offset', 'utc_offset'),
#                 ('la', 'la'),
#                 ('utc', 'utc'),
#                 ('latns', 'latns'),
#                 ('longew', 'longew'),
#                 ('longd', 'longd'),
#                 ('latd', 'latd'),
#                 ('latm', 'latm'),
#                 ('longm', 'longm'),
#                 ('lats', 'lats'),
#                 ('longs', 'longs'),
#                 ('rd', 'rd'),
#                 ('di', 'di'),
#                 ('}}', '}}'),
#                 ('utc_offset_dst', 'utc_offset_dst'),
#                 ('timezone_dst', 'timezone_dst'),
#                 ('score', 'score'),
#                 ('new', 'new'),
#                 ('km', 'km'),
#                 ('to', 'to'),
#                 ('album', 'album'),
#                 ('align', 'align'),
#                 ('eet', 'eet'),
#                 ('eest', 'eest'),
#                 ('ii', 'ii'),
#                 ('goals', 'goals'),
#                 ('blank', 'blank'),
#                 ('on', 'on'),
#                 ('san', 'san'),
#                 ('style', 'style'),
#                 ('list', 'list'),
#                 ('for', 'for'),
#                 ('mm', 'mm'),
#                 ('website', 'website'),
#                 ('world', 'world'),
#                 ('right', 'right'),
#                 ('isbn', 'isbn'),
#                 ('}}}', '}}}'),
#                 ('width', 'width'),
#                 ('saint', 'saint'),
#                 ('club', 'club'),
#                 ('top', 'top'),
#                 ('wikipedia', 'wikipedia'),
#                 ('px', 'px'),
#                 ('left', 'left'),
#                 ('caps', 'caps'),
#                 ('et', 'et'),
#                 ('color', 'color'),
#                 ('by', 'by'),
#                 ('john', 'john'),
#                 ('is', 'is'),
#                 ('data', 'data')]},
#               'ja': {'num': 20,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('text', 'text'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('de', 'de'),
#                 ('in', 'in'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('km', 'km'),
#                 ('to', 'to'),
#                 ('align', 'align'),
#                 ('ii', 'ii'),
#                 ('on', 'on'),
#                 ('style', 'style'),
#                 ('for', 'for'),
#                 ('mm', 'mm'),
#                 ('isbn', 'isbn')]},
#               'zh': {'num': 25,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('text', 'text'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('de', 'de'),
#                 ('in', 'in'),
#                 ('utc', 'utc'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('to', 'to'),
#                 ('align', 'align'),
#                 ('goals', 'goals'),
#                 ('on', 'on'),
#                 ('style', 'style'),
#                 ('list', 'list'),
#                 ('for', 'for'),
#                 ('right', 'right'),
#                 ('isbn', 'isbn'),
#                 ('wikipedia', 'wikipedia'),
#                 ('px', 'px'),
#                 ('left', 'left'),
#                 ('color', 'color'),
#                 ('by', 'by')]},
#               'th': {'num': 23,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('text', 'text'),
#                 ('and', 'and'),
#                 ('jpg', 'jpg'),
#                 ('from', 'from'),
#                 ('at', 'at'),
#                 ('in', 'in'),
#                 ('rd', 'rd'),
#                 ('score', 'score'),
#                 ('to', 'to'),
#                 ('align', 'align'),
#                 ('goals', 'goals'),
#                 ('on', 'on'),
#                 ('style', 'style'),
#                 ('for', 'for'),
#                 ('width', 'width'),
#                 ('px', 'px'),
#                 ('color', 'color'),
#                 ('by', 'by'),
#                 ('is', 'is'),
#                 ('data', 'data')]}},
#              'th': {'num_words': '107774',
#               'max_vocab': 1000,
#               'en': {'num': 31,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('goals', 'goals'),
#                 ('www', 'www'),
#                 ('http', 'http'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('data', 'data'),
#                 ('is', 'is'),
#                 ('score', 'score'),
#                 ('by', 'by'),
#                 ('team', 'team'),
#                 ('stadium', 'stadium'),
#                 ('color', 'color'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('group', 'group'),
#                 ('th', 'th'),
#                 ('at', 'at')]},
#               'de': {'num': 20,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('http', 'http'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('at', 'at')]},
#               'es': {'num': 24,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('px', 'px'),
#                 ('http', 'http'),
#                 ('svg', 'svg'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('color', 'color'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('width', 'width')]},
#               'it': {'num': 23,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('http', 'http'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('data', 'data'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('color', 'color'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('at', 'at'),
#                 ('width', 'width')]},
#               'fi': {'num': 24,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('px', 'px'),
#                 ('www', 'www'),
#                 ('http', 'http'),
#                 ('svg', 'svg'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('is', 'is'),
#                 ('color', 'color'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('at', 'at')]},
#               'ar': {'num': 27,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('px', 'px'),
#                 ('http', 'http'),
#                 ('svg', 'svg'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('png', 'png'),
#                 ('is', 'is'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('color', 'color'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('at', 'at'),
#                 ('width', 'width')]},
#               'he': {'num': 10,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('to', 'to'),
#                 ('jpg', 'jpg'),
#                 ('svg', 'svg'),
#                 ('score', 'score'),
#                 ('rd', 'rd')]},
#               'ms': {'num': 32,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('px', 'px'),
#                 ('goals', 'goals'),
#                 ('http', 'http'),
#                 ('svg', 'svg'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('data', 'data'),
#                 ('is', 'is'),
#                 ('score', 'score'),
#                 ('by', 'by'),
#                 ('team', 'team'),
#                 ('stadium', 'stadium'),
#                 ('color', 'color'),
#                 ('with', 'with'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('group', 'group'),
#                 ('at', 'at'),
#                 ('width', 'width')]},
#               'ja': {'num': 17,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('www', 'www'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('score', 'score'),
#                 ('team', 'team'),
#                 ('rd', 'rd')]},
#               'zh': {'num': 25,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('center', 'center'),
#                 ('jpg', 'jpg'),
#                 ('com', 'com'),
#                 ('for', 'for'),
#                 ('border', 'border'),
#                 ('px', 'px'),
#                 ('goals', 'goals'),
#                 ('www', 'www'),
#                 ('http', 'http'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('score', 'score'),
#                 ('by', 'by'),
#                 ('team', 'team'),
#                 ('color', 'color'),
#                 ('rd', 'rd'),
#                 ('group', 'group')]},
#               'vi': {'num': 23,
#                'pairs': [('</s>', '</s>'),
#                 ('the', 'the'),
#                 ('of', 'of'),
#                 ('and', 'and'),
#                 ('in', 'in'),
#                 ('align', 'align'),
#                 ('style', 'style'),
#                 ('to', 'to'),
#                 ('jpg', 'jpg'),
#                 ('for', 'for'),
#                 ('px', 'px'),
#                 ('goals', 'goals'),
#                 ('on', 'on'),
#                 ('text', 'text'),
#                 ('data', 'data'),
#                 ('is', 'is'),
#                 ('score', 'score'),
#                 ('by', 'by'),
#                 ('color', 'color'),
#                 ('from', 'from'),
#                 ('rd', 'rd'),
#                 ('at', 'at'),
#                 ('width', 'width')]}}})

# %%
# max_vocab = 1000
iden_num
# Out:
# defaultdict(dict,
#             {'en': {'num_words': '2519370',
#               'max_vocab': 1000,
#               'de': 150,
#               'es': 140,
#               'it': 141,
#               'fi': 128,
#               'ar': 75,
#               'he': 44,
#               'ms': 163,
#               'ja': 66,
#               'zh': 84,
#               'vi': 96,
#               'th': 63},
#              'de': {'num_words': '2275233',
#               'max_vocab': 1000,
#               'en': 150,
#               'es': 110,
#               'it': 128,
#               'fi': 110,
#               'ar': 65,
#               'he': 43,
#               'ms': 116,
#               'ja': 67,
#               'zh': 67,
#               'vi': 81,
#               'th': 52},
#              'es': {'num_words': '985667',
#               'max_vocab': 1000,
#               'en': 140,
#               'de': 110,
#               'it': 208,
#               'fi': 107,
#               'ar': 72,
#               'he': 44,
#               'ms': 109,
#               'ja': 67,
#               'zh': 69,
#               'vi': 83,
#               'th': 56},
#              'it': {'num_words': '871053',
#               'max_vocab': 1000,
#               'en': 141,
#               'de': 128,
#               'es': 208,
#               'fi': 120,
#               'ar': 65,
#               'he': 39,
#               'ms': 104,
#               'ja': 66,
#               'zh': 67,
#               'vi': 91,
#               'th': 54},
#              'fi': {'num_words': '730483',
#               'max_vocab': 1000,
#               'en': 128,
#               'de': 110,
#               'es': 107,
#               'it': 120,
#               'ar': 69,
#               'he': 44,
#               'ms': 105,
#               'ja': 67,
#               'zh': 68,
#               'vi': 78,
#               'th': 56},
#              'ar': {'num_words': '610977',
#               'max_vocab': 1000,
#               'en': 75,
#               'de': 65,
#               'es': 72,
#               'it': 65,
#               'fi': 69,
#               'he': 47,
#               'ms': 86,
#               'ja': 55,
#               'zh': 66,
#               'vi': 72,
#               'th': 58},
#              'he': {'num_words': '488936',
#               'max_vocab': 1000,
#               'en': 44,
#               'de': 43,
#               'es': 44,
#               'it': 39,
#               'fi': 44,
#               'ar': 47,
#               'ms': 45,
#               'ja': 40,
#               'zh': 42,
#               'vi': 41,
#               'th': 40},
#              'ms': {'num_words': '155629',
#               'max_vocab': 1000,
#               'en': 163,
#               'de': 116,
#               'es': 109,
#               'it': 104,
#               'fi': 105,
#               'ar': 86,
#               'he': 45,
#               'ja': 67,
#               'zh': 79,
#               'vi': 106,
#               'th': 63},
#              'ja': {'num_words': '580000',
#               'max_vocab': 1000,
#               'en': 66,
#               'de': 67,
#               'es': 67,
#               'it': 66,
#               'fi': 67,
#               'ar': 55,
#               'he': 40,
#               'ms': 67,
#               'zh': 319,
#               'vi': 58,
#               'th': 49},
#              'zh': {'num_words': '332647',
#               'max_vocab': 1000,
#               'en': 84,
#               'de': 67,
#               'es': 69,
#               'it': 67,
#               'fi': 68,
#               'ar': 66,
#               'he': 42,
#               'ms': 79,
#               'ja': 319,
#               'vi': 63,
#               'th': 57},
#              'vi': {'num_words': '292168',
#               'max_vocab': 1000,
#               'en': 96,
#               'de': 81,
#               'es': 83,
#               'it': 91,
#               'fi': 78,
#               'ar': 72,
#               'he': 41,
#               'ms': 106,
#               'ja': 58,
#               'zh': 63,
#               'th': 53},
#              'th': {'num_words': '107774',
#               'max_vocab': 1000,
#               'en': 63,
#               'de': 52,
#               'es': 56,
#               'it': 54,
#               'fi': 56,
#               'ar': 58,
#               'he': 40,
#               'ms': 63,
#               'ja': 49,
#               'zh': 57,
#               'vi': 53}})
